# %% [markdown]
# # Example of the Tensorflow to TensorRT converter
#
# The Tensorflow network needs to be in float32 und the internal data format should be 'NCHW' ('channel_first').

# %%
import io
import os
import time
import tarfile
import requests

# use the first GPU in the system
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import numpy as np
import tensorrt as trt
import tensorflow as tf

from trt_importer import TRTImporter




# variables
input_op = "input_tensor"
input_shape = [1, 224, 224, 3]
output_op = "softmax_tensor"
    
# example data
np.random.seed(7)
np_input = np.random.rand(*input_shape) * 255
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Download and extract a ResNet50 model from Tensorflow

# %%
response = requests.get("http://download.tensorflow.org/models/official/20181001_resnet/savedmodels/resnet_v2_fp32_savedmodel_NCHW.tar.gz")

# download and read the tar content
with tarfile.open(fileobj=io.BytesIO(response.content), mode='r:gz') as tar:
    for member in tar:
        print(member)
    tar.extractall(".")
# Out:
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW' at 0x7ff15c4d2a10>
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW/1538687196' at 0x7ff15c4d2bb0>
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW/1538687196/variables' at 0x7ff15c4d2ae0>
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW/1538687196/variables/variables.index' at 0x7ff15c4d2c80>
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW/1538687196/variables/variables.data-00000-of-00001' at 0x7ff15c4d2d50>
# <TarInfo './resnet_v2_fp32_savedmodel_NCHW/1538687196/saved_model.pb' at 0x7ff15c4d2ef0>

# %% [markdown]
# ## Load the saved model and convert it into a frozen graph

# %%
from tensorflow.python.tools import strip_unused_lib

config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory usage

with tf.Session(graph=tf.Graph(), config=config) as session:
    tf.saved_model.loader.load(session, ["serve"], "resnet_v2_fp32_savedmodel_NCHW/1538687196")
    print("Loaded saved model with ",len(session.graph_def.node),"nodes")
    
    # creates a subgraph with only the needed nodes
    output_graph_def = tf.compat.v1.graph_util.convert_variables_to_constants(session, session.graph_def, [output_op])
    print("Converted to frozen graph with ",len(output_graph_def.node),"nodes")
    
    # remove batch sizes information
    output_graph_def = strip_unused_lib.strip_unused(output_graph_def,
                                                     input_node_names=[input_op],
                                                     output_node_names=[output_op],
                                                     placeholder_type_enum=tf.float32.as_datatype_enum)
    print("Strip unnessesary data. Resulting graph has",len(output_graph_def.node),"nodes.")
    
    # remove training and saver nodes
    output_graph_def = tf.compat.v1.graph_util.remove_training_nodes(output_graph_def)
    print("Final graph has",len(output_graph_def.node),"nodes, after removing training nodes")
# Out:
# WARNING:tensorflow:From <ipython-input-3-3f69af7f303b>:7: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/tensorrt/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from resnet_v2_fp32_savedmodel_NCHW/1538687196/variables/variables
# Loaded saved model with  1932 nodes
# WARNING:tensorflow:From <ipython-input-3-3f69af7f303b>:11: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/administrator/anaconda3/envs/tensorrt/lib/python3.7/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 251 variables.
# INFO:tensorflow:Converted 251 variables to const ops.
# Converted to frozen graph with  701 nodes
# Strip unnessesary data. Resulting graph has 701 nodes.
# WARNING:tensorflow:From <ipython-input-3-3f69af7f303b>:22: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.remove_training_nodes`
# Final graph has 442 nodes, after removing training nodes

# %% [markdown]
# ## Convert the Tensorflow network into a TensorRT engine

# %%
importer = TRTImporter(trt.Logger.VERBOSE)
network = importer.from_tensorflow_graph_def(output_graph_def, [input_op], [input_shape], [output_op])
serialized_engine = importer.optimize_network(network, max_batch_size=1, max_workspace_size=4 * (1 << 30), fast_pass=True)
importer.store_engine(serialized_engine, "resnet_v2_fp32_savedmodel_NCHW.engine")
# Out:
# add input_tensor (1, 224, 224, 3)
# add resnet_model/transpose/perm (4,)
# add resnet_model/transpose (1, 3, 224, 224)
# add resnet_model/Pad/paddings (4, 2)
# add resnet_model/Pad (1, 3, 230, 230)
# add resnet_model/conv2d/kernel (7, 7, 3, 64)
# add resnet_model/conv2d/Conv2D (1, 64, 112, 112)
# add resnet_model/max_pooling2d/MaxPool (1, 64, 56, 56)
# add resnet_model/batch_normalization/gamma (64,)
# add resnet_model/batch_normalization/beta (64,)
# add resnet_model/batch_normalization/moving_mean (64,)
# add resnet_model/batch_normalization/moving_variance (64,)
# add resnet_model/batch_normalization/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu (1, 64, 56, 56)
# add resnet_model/conv2d_1/kernel (1, 1, 64, 256)
# add resnet_model/conv2d_1/Conv2D (1, 256, 56, 56)
# add resnet_model/conv2d_2/kernel (1, 1, 64, 64)
# add resnet_model/conv2d_2/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_1/gamma (64,)
# add resnet_model/batch_normalization_1/beta (64,)
# add resnet_model/batch_normalization_1/moving_mean (64,)
# add resnet_model/batch_normalization_1/moving_variance (64,)
# add resnet_model/batch_normalization_1/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_1 (1, 64, 56, 56)
# add resnet_model/conv2d_3/kernel (3, 3, 64, 64)
# add resnet_model/conv2d_3/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_2/gamma (64,)
# add resnet_model/batch_normalization_2/beta (64,)
# add resnet_model/batch_normalization_2/moving_mean (64,)
# add resnet_model/batch_normalization_2/moving_variance (64,)
# add resnet_model/batch_normalization_2/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_2 (1, 64, 56, 56)
# add resnet_model/conv2d_4/kernel (1, 1, 64, 256)
# add resnet_model/conv2d_4/Conv2D (1, 256, 56, 56)
# add resnet_model/add (1, 256, 56, 56)
# add resnet_model/batch_normalization_3/gamma (256,)
# add resnet_model/batch_normalization_3/beta (256,)
# add resnet_model/batch_normalization_3/moving_mean (256,)
# add resnet_model/batch_normalization_3/moving_variance (256,)
# add resnet_model/batch_normalization_3/FusedBatchNorm (1, 256, 56, 56)
# add resnet_model/Relu_3 (1, 256, 56, 56)
# add resnet_model/conv2d_5/kernel (1, 1, 256, 64)
# add resnet_model/conv2d_5/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_4/gamma (64,)
# add resnet_model/batch_normalization_4/beta (64,)
# add resnet_model/batch_normalization_4/moving_mean (64,)
# add resnet_model/batch_normalization_4/moving_variance (64,)
# add resnet_model/batch_normalization_4/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_4 (1, 64, 56, 56)
# add resnet_model/conv2d_6/kernel (3, 3, 64, 64)
# add resnet_model/conv2d_6/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_5/gamma (64,)
# add resnet_model/batch_normalization_5/beta (64,)
# add resnet_model/batch_normalization_5/moving_mean (64,)
# add resnet_model/batch_normalization_5/moving_variance (64,)
# add resnet_model/batch_normalization_5/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_5 (1, 64, 56, 56)
# add resnet_model/conv2d_7/kernel (1, 1, 64, 256)
# add resnet_model/conv2d_7/Conv2D (1, 256, 56, 56)
# add resnet_model/add_1 (1, 256, 56, 56)
# add resnet_model/batch_normalization_6/gamma (256,)
# add resnet_model/batch_normalization_6/beta (256,)
# add resnet_model/batch_normalization_6/moving_mean (256,)
# add resnet_model/batch_normalization_6/moving_variance (256,)
# add resnet_model/batch_normalization_6/FusedBatchNorm (1, 256, 56, 56)
# add resnet_model/Relu_6 (1, 256, 56, 56)
# add resnet_model/conv2d_8/kernel (1, 1, 256, 64)
# add resnet_model/conv2d_8/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_7/gamma (64,)
# add resnet_model/batch_normalization_7/beta (64,)
# add resnet_model/batch_normalization_7/moving_mean (64,)
# add resnet_model/batch_normalization_7/moving_variance (64,)
# add resnet_model/batch_normalization_7/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_7 (1, 64, 56, 56)
# add resnet_model/conv2d_9/kernel (3, 3, 64, 64)
# add resnet_model/conv2d_9/Conv2D (1, 64, 56, 56)
# add resnet_model/batch_normalization_8/gamma (64,)
# add resnet_model/batch_normalization_8/beta (64,)
# add resnet_model/batch_normalization_8/moving_mean (64,)
# add resnet_model/batch_normalization_8/moving_variance (64,)
# add resnet_model/batch_normalization_8/FusedBatchNorm (1, 64, 56, 56)
# add resnet_model/Relu_8 (1, 64, 56, 56)
# add resnet_model/conv2d_10/kernel (1, 1, 64, 256)
# add resnet_model/conv2d_10/Conv2D (1, 256, 56, 56)
# add resnet_model/add_2 (1, 256, 56, 56)
# add resnet_model/batch_normalization_9/gamma (256,)
# add resnet_model/batch_normalization_9/beta (256,)
# add resnet_model/batch_normalization_9/moving_mean (256,)
# add resnet_model/batch_normalization_9/moving_variance (256,)
# add resnet_model/batch_normalization_9/FusedBatchNorm (1, 256, 56, 56)
# add resnet_model/Relu_9 (1, 256, 56, 56)
# add resnet_model/Pad_1/paddings (4, 2)
# add resnet_model/Pad_1 (1, 256, 56, 56)
# add resnet_model/conv2d_11/kernel (1, 1, 256, 512)
# add resnet_model/conv2d_11/Conv2D (1, 512, 28, 28)
# add resnet_model/conv2d_12/kernel (1, 1, 256, 128)
# add resnet_model/conv2d_12/Conv2D (1, 128, 56, 56)
# add resnet_model/batch_normalization_10/gamma (128,)
# add resnet_model/batch_normalization_10/beta (128,)
# add resnet_model/batch_normalization_10/moving_mean (128,)
# add resnet_model/batch_normalization_10/moving_variance (128,)
# add resnet_model/batch_normalization_10/FusedBatchNorm (1, 128, 56, 56)
# add resnet_model/Relu_10 (1, 128, 56, 56)
# add resnet_model/Pad_2/paddings (4, 2)
# add resnet_model/Pad_2 (1, 128, 58, 58)
# add resnet_model/conv2d_13/kernel (3, 3, 128, 128)
# add resnet_model/conv2d_13/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_11/gamma (128,)
# add resnet_model/batch_normalization_11/beta (128,)
# add resnet_model/batch_normalization_11/moving_mean (128,)
# add resnet_model/batch_normalization_11/moving_variance (128,)
# add resnet_model/batch_normalization_11/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_11 (1, 128, 28, 28)
# add resnet_model/conv2d_14/kernel (1, 1, 128, 512)
# add resnet_model/conv2d_14/Conv2D (1, 512, 28, 28)
# add resnet_model/add_3 (1, 512, 28, 28)
# add resnet_model/batch_normalization_12/gamma (512,)
# add resnet_model/batch_normalization_12/beta (512,)
# add resnet_model/batch_normalization_12/moving_mean (512,)
# add resnet_model/batch_normalization_12/moving_variance (512,)
# add resnet_model/batch_normalization_12/FusedBatchNorm (1, 512, 28, 28)
# add resnet_model/Relu_12 (1, 512, 28, 28)
# add resnet_model/conv2d_15/kernel (1, 1, 512, 128)
# add resnet_model/conv2d_15/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_13/gamma (128,)
# add resnet_model/batch_normalization_13/beta (128,)
# add resnet_model/batch_normalization_13/moving_mean (128,)
# add resnet_model/batch_normalization_13/moving_variance (128,)
# add resnet_model/batch_normalization_13/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_13 (1, 128, 28, 28)
# add resnet_model/conv2d_16/kernel (3, 3, 128, 128)
# add resnet_model/conv2d_16/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_14/gamma (128,)
# add resnet_model/batch_normalization_14/beta (128,)
# add resnet_model/batch_normalization_14/moving_mean (128,)
# add resnet_model/batch_normalization_14/moving_variance (128,)
# add resnet_model/batch_normalization_14/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_14 (1, 128, 28, 28)
# add resnet_model/conv2d_17/kernel (1, 1, 128, 512)
# add resnet_model/conv2d_17/Conv2D (1, 512, 28, 28)
# add resnet_model/add_4 (1, 512, 28, 28)
# add resnet_model/batch_normalization_15/gamma (512,)
# add resnet_model/batch_normalization_15/beta (512,)
# add resnet_model/batch_normalization_15/moving_mean (512,)
# add resnet_model/batch_normalization_15/moving_variance (512,)
# add resnet_model/batch_normalization_15/FusedBatchNorm (1, 512, 28, 28)
# add resnet_model/Relu_15 (1, 512, 28, 28)
# add resnet_model/conv2d_18/kernel (1, 1, 512, 128)
# add resnet_model/conv2d_18/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_16/gamma (128,)
# add resnet_model/batch_normalization_16/beta (128,)
# add resnet_model/batch_normalization_16/moving_mean (128,)
# add resnet_model/batch_normalization_16/moving_variance (128,)
# add resnet_model/batch_normalization_16/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_16 (1, 128, 28, 28)
# add resnet_model/conv2d_19/kernel (3, 3, 128, 128)
# add resnet_model/conv2d_19/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_17/gamma (128,)
# add resnet_model/batch_normalization_17/beta (128,)
# add resnet_model/batch_normalization_17/moving_mean (128,)
# add resnet_model/batch_normalization_17/moving_variance (128,)
# add resnet_model/batch_normalization_17/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_17 (1, 128, 28, 28)
# add resnet_model/conv2d_20/kernel (1, 1, 128, 512)
# add resnet_model/conv2d_20/Conv2D (1, 512, 28, 28)
# add resnet_model/add_5 (1, 512, 28, 28)
# add resnet_model/batch_normalization_18/gamma (512,)
# add resnet_model/batch_normalization_18/beta (512,)
# add resnet_model/batch_normalization_18/moving_mean (512,)
# add resnet_model/batch_normalization_18/moving_variance (512,)
# add resnet_model/batch_normalization_18/FusedBatchNorm (1, 512, 28, 28)
# add resnet_model/Relu_18 (1, 512, 28, 28)
# add resnet_model/conv2d_21/kernel (1, 1, 512, 128)
# add resnet_model/conv2d_21/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_19/gamma (128,)
# add resnet_model/batch_normalization_19/beta (128,)
# add resnet_model/batch_normalization_19/moving_mean (128,)
# add resnet_model/batch_normalization_19/moving_variance (128,)
# add resnet_model/batch_normalization_19/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_19 (1, 128, 28, 28)
# add resnet_model/conv2d_22/kernel (3, 3, 128, 128)
# add resnet_model/conv2d_22/Conv2D (1, 128, 28, 28)
# add resnet_model/batch_normalization_20/gamma (128,)
# add resnet_model/batch_normalization_20/beta (128,)
# add resnet_model/batch_normalization_20/moving_mean (128,)
# add resnet_model/batch_normalization_20/moving_variance (128,)
# add resnet_model/batch_normalization_20/FusedBatchNorm (1, 128, 28, 28)
# add resnet_model/Relu_20 (1, 128, 28, 28)
# add resnet_model/conv2d_23/kernel (1, 1, 128, 512)
# add resnet_model/conv2d_23/Conv2D (1, 512, 28, 28)
# add resnet_model/add_6 (1, 512, 28, 28)
# add resnet_model/batch_normalization_21/gamma (512,)
# add resnet_model/batch_normalization_21/beta (512,)
# add resnet_model/batch_normalization_21/moving_mean (512,)
# add resnet_model/batch_normalization_21/moving_variance (512,)
# add resnet_model/batch_normalization_21/FusedBatchNorm (1, 512, 28, 28)
# add resnet_model/Relu_21 (1, 512, 28, 28)
# add resnet_model/Pad_3/paddings (4, 2)
# add resnet_model/Pad_3 (1, 512, 28, 28)
# add resnet_model/conv2d_24/kernel (1, 1, 512, 1024)
# add resnet_model/conv2d_24/Conv2D (1, 1024, 14, 14)
# add resnet_model/conv2d_25/kernel (1, 1, 512, 256)
# add resnet_model/conv2d_25/Conv2D (1, 256, 28, 28)
# add resnet_model/batch_normalization_22/gamma (256,)
# add resnet_model/batch_normalization_22/beta (256,)
# add resnet_model/batch_normalization_22/moving_mean (256,)
# add resnet_model/batch_normalization_22/moving_variance (256,)
# add resnet_model/batch_normalization_22/FusedBatchNorm (1, 256, 28, 28)
# add resnet_model/Relu_22 (1, 256, 28, 28)
# add resnet_model/Pad_4/paddings (4, 2)
# add resnet_model/Pad_4 (1, 256, 30, 30)
# add resnet_model/conv2d_26/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_26/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_23/gamma (256,)
# add resnet_model/batch_normalization_23/beta (256,)
# add resnet_model/batch_normalization_23/moving_mean (256,)
# add resnet_model/batch_normalization_23/moving_variance (256,)
# add resnet_model/batch_normalization_23/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_23 (1, 256, 14, 14)
# add resnet_model/conv2d_27/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_27/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_7 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_24/gamma (1024,)
# add resnet_model/batch_normalization_24/beta (1024,)
# add resnet_model/batch_normalization_24/moving_mean (1024,)
# add resnet_model/batch_normalization_24/moving_variance (1024,)
# add resnet_model/batch_normalization_24/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_24 (1, 1024, 14, 14)
# add resnet_model/conv2d_28/kernel (1, 1, 1024, 256)
# add resnet_model/conv2d_28/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_25/gamma (256,)
# add resnet_model/batch_normalization_25/beta (256,)
# add resnet_model/batch_normalization_25/moving_mean (256,)
# add resnet_model/batch_normalization_25/moving_variance (256,)
# add resnet_model/batch_normalization_25/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_25 (1, 256, 14, 14)
# add resnet_model/conv2d_29/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_29/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_26/gamma (256,)
# add resnet_model/batch_normalization_26/beta (256,)
# add resnet_model/batch_normalization_26/moving_mean (256,)
# add resnet_model/batch_normalization_26/moving_variance (256,)
# add resnet_model/batch_normalization_26/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_26 (1, 256, 14, 14)
# add resnet_model/conv2d_30/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_30/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_8 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_27/gamma (1024,)
# add resnet_model/batch_normalization_27/beta (1024,)
# add resnet_model/batch_normalization_27/moving_mean (1024,)
# add resnet_model/batch_normalization_27/moving_variance (1024,)
# add resnet_model/batch_normalization_27/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_27 (1, 1024, 14, 14)
# add resnet_model/conv2d_31/kernel (1, 1, 1024, 256)
# add resnet_model/conv2d_31/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_28/gamma (256,)
# add resnet_model/batch_normalization_28/beta (256,)
# add resnet_model/batch_normalization_28/moving_mean (256,)
# add resnet_model/batch_normalization_28/moving_variance (256,)
# add resnet_model/batch_normalization_28/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_28 (1, 256, 14, 14)
# add resnet_model/conv2d_32/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_32/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_29/gamma (256,)
# add resnet_model/batch_normalization_29/beta (256,)
# add resnet_model/batch_normalization_29/moving_mean (256,)
# add resnet_model/batch_normalization_29/moving_variance (256,)
# add resnet_model/batch_normalization_29/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_29 (1, 256, 14, 14)
# add resnet_model/conv2d_33/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_33/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_9 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_30/gamma (1024,)
# add resnet_model/batch_normalization_30/beta (1024,)
# add resnet_model/batch_normalization_30/moving_mean (1024,)
# add resnet_model/batch_normalization_30/moving_variance (1024,)
# add resnet_model/batch_normalization_30/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_30 (1, 1024, 14, 14)
# add resnet_model/conv2d_34/kernel (1, 1, 1024, 256)
# add resnet_model/conv2d_34/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_31/gamma (256,)
# add resnet_model/batch_normalization_31/beta (256,)
# add resnet_model/batch_normalization_31/moving_mean (256,)
# add resnet_model/batch_normalization_31/moving_variance (256,)
# add resnet_model/batch_normalization_31/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_31 (1, 256, 14, 14)
# add resnet_model/conv2d_35/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_35/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_32/gamma (256,)
# add resnet_model/batch_normalization_32/beta (256,)
# add resnet_model/batch_normalization_32/moving_mean (256,)
# add resnet_model/batch_normalization_32/moving_variance (256,)
# add resnet_model/batch_normalization_32/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_32 (1, 256, 14, 14)
# add resnet_model/conv2d_36/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_36/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_10 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_33/gamma (1024,)
# add resnet_model/batch_normalization_33/beta (1024,)
# add resnet_model/batch_normalization_33/moving_mean (1024,)
# add resnet_model/batch_normalization_33/moving_variance (1024,)
# add resnet_model/batch_normalization_33/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_33 (1, 1024, 14, 14)
# add resnet_model/conv2d_37/kernel (1, 1, 1024, 256)
# add resnet_model/conv2d_37/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_34/gamma (256,)
# add resnet_model/batch_normalization_34/beta (256,)
# add resnet_model/batch_normalization_34/moving_mean (256,)
# add resnet_model/batch_normalization_34/moving_variance (256,)
# add resnet_model/batch_normalization_34/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_34 (1, 256, 14, 14)
# add resnet_model/conv2d_38/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_38/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_35/gamma (256,)
# add resnet_model/batch_normalization_35/beta (256,)
# add resnet_model/batch_normalization_35/moving_mean (256,)
# add resnet_model/batch_normalization_35/moving_variance (256,)
# add resnet_model/batch_normalization_35/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_35 (1, 256, 14, 14)
# add resnet_model/conv2d_39/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_39/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_11 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_36/gamma (1024,)
# add resnet_model/batch_normalization_36/beta (1024,)
# add resnet_model/batch_normalization_36/moving_mean (1024,)
# add resnet_model/batch_normalization_36/moving_variance (1024,)
# add resnet_model/batch_normalization_36/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_36 (1, 1024, 14, 14)
# add resnet_model/conv2d_40/kernel (1, 1, 1024, 256)
# add resnet_model/conv2d_40/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_37/gamma (256,)
# add resnet_model/batch_normalization_37/beta (256,)
# add resnet_model/batch_normalization_37/moving_mean (256,)
# add resnet_model/batch_normalization_37/moving_variance (256,)
# add resnet_model/batch_normalization_37/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_37 (1, 256, 14, 14)
# add resnet_model/conv2d_41/kernel (3, 3, 256, 256)
# add resnet_model/conv2d_41/Conv2D (1, 256, 14, 14)
# add resnet_model/batch_normalization_38/gamma (256,)
# add resnet_model/batch_normalization_38/beta (256,)
# add resnet_model/batch_normalization_38/moving_mean (256,)
# add resnet_model/batch_normalization_38/moving_variance (256,)
# add resnet_model/batch_normalization_38/FusedBatchNorm (1, 256, 14, 14)
# add resnet_model/Relu_38 (1, 256, 14, 14)
# add resnet_model/conv2d_42/kernel (1, 1, 256, 1024)
# add resnet_model/conv2d_42/Conv2D (1, 1024, 14, 14)
# add resnet_model/add_12 (1, 1024, 14, 14)
# add resnet_model/batch_normalization_39/gamma (1024,)
# add resnet_model/batch_normalization_39/beta (1024,)
# add resnet_model/batch_normalization_39/moving_mean (1024,)
# add resnet_model/batch_normalization_39/moving_variance (1024,)
# add resnet_model/batch_normalization_39/FusedBatchNorm (1, 1024, 14, 14)
# add resnet_model/Relu_39 (1, 1024, 14, 14)
# add resnet_model/Pad_5/paddings (4, 2)
# add resnet_model/Pad_5 (1, 1024, 14, 14)
# add resnet_model/conv2d_43/kernel (1, 1, 1024, 2048)
# add resnet_model/conv2d_43/Conv2D (1, 2048, 7, 7)
# add resnet_model/conv2d_44/kernel (1, 1, 1024, 512)
# add resnet_model/conv2d_44/Conv2D (1, 512, 14, 14)
# add resnet_model/batch_normalization_40/gamma (512,)
# add resnet_model/batch_normalization_40/beta (512,)
# add resnet_model/batch_normalization_40/moving_mean (512,)
# add resnet_model/batch_normalization_40/moving_variance (512,)
# add resnet_model/batch_normalization_40/FusedBatchNorm (1, 512, 14, 14)
# add resnet_model/Relu_40 (1, 512, 14, 14)
# add resnet_model/Pad_6/paddings (4, 2)
# add resnet_model/Pad_6 (1, 512, 16, 16)
# add resnet_model/conv2d_45/kernel (3, 3, 512, 512)
# add resnet_model/conv2d_45/Conv2D (1, 512, 7, 7)
# add resnet_model/batch_normalization_41/gamma (512,)
# add resnet_model/batch_normalization_41/beta (512,)
# add resnet_model/batch_normalization_41/moving_mean (512,)
# add resnet_model/batch_normalization_41/moving_variance (512,)
# add resnet_model/batch_normalization_41/FusedBatchNorm (1, 512, 7, 7)
# add resnet_model/Relu_41 (1, 512, 7, 7)
# add resnet_model/conv2d_46/kernel (1, 1, 512, 2048)
# add resnet_model/conv2d_46/Conv2D (1, 2048, 7, 7)
# add resnet_model/add_13 (1, 2048, 7, 7)
# add resnet_model/batch_normalization_42/gamma (2048,)
# add resnet_model/batch_normalization_42/beta (2048,)
# add resnet_model/batch_normalization_42/moving_mean (2048,)
# add resnet_model/batch_normalization_42/moving_variance (2048,)
# add resnet_model/batch_normalization_42/FusedBatchNorm (1, 2048, 7, 7)
# add resnet_model/Relu_42 (1, 2048, 7, 7)
# add resnet_model/conv2d_47/kernel (1, 1, 2048, 512)
# add resnet_model/conv2d_47/Conv2D (1, 512, 7, 7)
# add resnet_model/batch_normalization_43/gamma (512,)
# add resnet_model/batch_normalization_43/beta (512,)
# add resnet_model/batch_normalization_43/moving_mean (512,)
# add resnet_model/batch_normalization_43/moving_variance (512,)
# add resnet_model/batch_normalization_43/FusedBatchNorm (1, 512, 7, 7)
# add resnet_model/Relu_43 (1, 512, 7, 7)
# add resnet_model/conv2d_48/kernel (3, 3, 512, 512)
# add resnet_model/conv2d_48/Conv2D (1, 512, 7, 7)
# add resnet_model/batch_normalization_44/gamma (512,)
# add resnet_model/batch_normalization_44/beta (512,)
# add resnet_model/batch_normalization_44/moving_mean (512,)
# add resnet_model/batch_normalization_44/moving_variance (512,)
# add resnet_model/batch_normalization_44/FusedBatchNorm (1, 512, 7, 7)
# add resnet_model/Relu_44 (1, 512, 7, 7)
# add resnet_model/conv2d_49/kernel (1, 1, 512, 2048)
# add resnet_model/conv2d_49/Conv2D (1, 2048, 7, 7)
# add resnet_model/add_14 (1, 2048, 7, 7)
# add resnet_model/batch_normalization_45/gamma (2048,)
# add resnet_model/batch_normalization_45/beta (2048,)
# add resnet_model/batch_normalization_45/moving_mean (2048,)
# add resnet_model/batch_normalization_45/moving_variance (2048,)
# add resnet_model/batch_normalization_45/FusedBatchNorm (1, 2048, 7, 7)
# add resnet_model/Relu_45 (1, 2048, 7, 7)
# add resnet_model/conv2d_50/kernel (1, 1, 2048, 512)
# add resnet_model/conv2d_50/Conv2D (1, 512, 7, 7)
# add resnet_model/batch_normalization_46/gamma (512,)
# add resnet_model/batch_normalization_46/beta (512,)
# add resnet_model/batch_normalization_46/moving_mean (512,)
# add resnet_model/batch_normalization_46/moving_variance (512,)
# add resnet_model/batch_normalization_46/FusedBatchNorm (1, 512, 7, 7)
# add resnet_model/Relu_46 (1, 512, 7, 7)
# add resnet_model/conv2d_51/kernel (3, 3, 512, 512)
# add resnet_model/conv2d_51/Conv2D (1, 512, 7, 7)
# add resnet_model/batch_normalization_47/gamma (512,)
# add resnet_model/batch_normalization_47/beta (512,)
# add resnet_model/batch_normalization_47/moving_mean (512,)
# add resnet_model/batch_normalization_47/moving_variance (512,)
# add resnet_model/batch_normalization_47/FusedBatchNorm (1, 512, 7, 7)
# add resnet_model/Relu_47 (1, 512, 7, 7)
# add resnet_model/conv2d_52/kernel (1, 1, 512, 2048)
# add resnet_model/conv2d_52/Conv2D (1, 2048, 7, 7)
# add resnet_model/add_15 (1, 2048, 7, 7)
# add resnet_model/batch_normalization_48/gamma (2048,)
# add resnet_model/batch_normalization_48/beta (2048,)
# add resnet_model/batch_normalization_48/moving_mean (2048,)
# add resnet_model/batch_normalization_48/moving_variance (2048,)
# add resnet_model/batch_normalization_48/FusedBatchNorm (1, 2048, 7, 7)
# add resnet_model/Relu_48 (1, 2048, 7, 7)
# add resnet_model/Mean/reduction_indices (2,)
# add resnet_model/Mean (1, 2048, 1, 1)
# input shape (1, 2048, 1, 1) rank 4 for layer resnet_model/Squeeze
# new_shape [1, 2048] shape (1, 2048, 1, 1) squeeze_dims [2 3]
# add resnet_model/Squeeze (1, 2048)
# add resnet_model/dense/kernel (2048, 1001)
# add resnet_model/dense/bias (1001,)
# add resnet_model/dense/MatMul (1, 1001)
# add resnet_model/dense/BiasAdd_broadcast_bias (1, 1001)
# add resnet_model/dense/BiasAdd (1, 1001)
# add softmax_tensor (1, 1001)
# max_workspace_size 4294967296
# average_find_iterations 1
# min_find_iterations 1
# finished building an engine in 38.10 [sec]
# num_layers 79
# device_memory_size 10035200
# stored TensorRT engine resnet_v2_fp32_savedmodel_NCHW.engine
# True

# %% [markdown]
# ## Load the engine and run an inference pass

# %%
importer = TRTImporter(trt.Logger.VERBOSE)
serialized_engine = importer.load_engine("resnet_v2_fp32_savedmodel_NCHW.engine")

# %%
inference_context = importer.inference_engine(serialized_engine)

print("\nBinding of input and output tensors")
print(inference_context.get_input_bindings())
print(inference_context.get_output_bindings())
# Out:
# Plugin after: 0 [msec]
# Runtime after: 190 [msec]
# Deserialize Cuda engine after: 1479 [msec]
# Create execution context after: 1480 [msec]
# Setup bindings after: 1481 [msec]
# All shapes are known True
# All dynamic shapes are known True
#
# Binding of input and output tensors
# {'input_tensor': Binding of input_tensor
# Shape:(1, 224, 224, 3)
# Host:[0. 0. 0. ... 0. 0. 0.]
# Device:<pycuda._driver.DeviceAllocation object at 0x7ff0d84c9b70>
# IsInput:True}
# [Binding of softmax_tensor
# Shape:(1, 1001)
# Host:[0. 0. 0. ... 0. 0. 0.]
# Device:<pycuda._driver.DeviceAllocation object at 0x7ff0d84c9710>
# IsInput:False]

# %%
for i in range(10):
    start = time.time()
    output = inference_context.run(feed_dict={input_op: np_input})
    print('Inference time: {} [msec]'.format((time.time() - start)*1000))
trt_output = output[output_op]
# Out:
# Inference time: 3.821849822998047 [msec]
# Inference time: 88.60540390014648 [msec]
# Inference time: 3.4532546997070312 [msec]
# Inference time: 3.397226333618164 [msec]
# Inference time: 3.401517868041992 [msec]
# Inference time: 3.381013870239258 [msec]
# Inference time: 3.4008026123046875 [msec]
# Inference time: 3.411531448364258 [msec]
# Inference time: 3.4499168395996094 [msec]
# Inference time: 3.4148693084716797 [msec]

# %%
trt_output
# Out:
# array([[5.1498625e-07, 1.7150540e-05, 1.7791535e-04, ..., 1.5762380e-06,
#         5.4471198e-05, 3.7366131e-05]], dtype=float32)

# %%
del inference_context

# %% [markdown]
# ## Run a simple test image in Tensorflow to get reference results

# %%
# create a new graph and use it as the default graph
graph = tf.Graph()
with graph.as_default():
    nodes = tf.import_graph_def(output_graph_def, name='', return_elements=[input_op, output_op])
    tf_input_tensor = nodes[0].outputs[0]
    tf_output_tensor = nodes[1].outputs[0]
    
    print(tf_input_tensor)
    print(tf_output_tensor)
    
with tf.Session(graph=graph, config=config) as session:
    
    # time
    for i in range(10):
        start = time.time()
        tf_output = session.run(tf_output_tensor, feed_dict={tf_input_tensor: np_input})
        print('Inference time: {} [msec]'.format((time.time() - start)*1000))
    print("Output shape", tf_output.shape)
# Out:
# Tensor("input_tensor:0", dtype=float32)
# Tensor("softmax_tensor:0", shape=(?, 1001), dtype=float32)
# Inference time: 1433.9814186096191 [msec]
# Inference time: 7.35020637512207 [msec]
# Inference time: 7.376432418823242 [msec]
# Inference time: 7.016897201538086 [msec]
# Inference time: 7.330894470214844 [msec]
# Inference time: 7.456779479980469 [msec]
# Inference time: 7.67970085144043 [msec]
# Inference time: 7.307291030883789 [msec]
# Inference time: 7.283926010131836 [msec]
# Inference time: 7.1563720703125 [msec]
# Output shape (1, 1001)

# %% [markdown]
# ## Compare the results

# %%
print("difference between TensorRT and Tensorflow:", np.sum(np.abs(tf_output-trt_output)))
print(trt_output)
# Out:
# difference between TensorRT and Tensorflow: 1.6834913e-06
# [[5.1498625e-07 1.7150540e-05 1.7791535e-04 ... 1.5762380e-06
#   5.4471198e-05 3.7366131e-05]]
